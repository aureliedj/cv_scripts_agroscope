# %%
import cv2
from glob import glob
import matplotlib.pyplot as plt
import utils
import rawpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# \profiles$\RDF\F80860485\Desktop\Projets\Wheat_cameras\viz_img.ipynb Cell 1' in <cell line: 5>()
#       <a href='vscode-notebook-cell://ags-fs-profiles/profiles%24/RDF/F80860485/Desktop/Projets/Wheat_cameras/viz_img.ipynb#ch0000000?line=2'>3</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell://ags-fs-profiles/profiles%24/RDF/F80860485/Desktop/Projets/Wheat_cameras/viz_img.ipynb#ch0000000?line=3'>4</a> import utils
# ----> <a href='vscode-notebook-cell://ags-fs-profiles/profiles%24/RDF/F80860485/Desktop/Projets/Wheat_cameras/viz_img.ipynb#ch0000000?line=4'>5</a> import rawpy
#
# ModuleNotFoundError: No module named 'rawpy'

# %%
#path = r'O:\Foto-Video-Research\22_Plant_Production-CH\224_Digitalisation\PhenotypingData\GroundPhenotyping\2021\FixPositionCameras_P4\2021\P4\Left_Mast_Lausanne\20210719_Innov'
path = r'\\ags-fs-profiles\profiles$\RDF\F80860485\Desktop'
paths = glob(path +'\\*LEFT*')

# %%
list_images = []

for p in paths:
    list_images.append(cv2.imread(p))

# %%
blurred_img = utils.infoBlur(list_images, True)
# Out:
# Image is blurry True, var 83.0864675971655
# Image is blurry True, var 74.13744970526739
# Image is blurry False, var 1669.7942237950097
