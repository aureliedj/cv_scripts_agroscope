# %%
import os
from crop_frame import DebugArgs, crop
from glob import glob
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
input_dir = os.getcwd() + '/../../../data/photos_zenitales/2022.09.08'
# create output directory
if input_dir + '_crop' not in glob(input_dir +'_crop'):
    output_dir = os.makedirs(input_dir + '_crop')
else:
    output_dir = input_dir + '_crop'

# %%
args = DebugArgs(input_dir, output_dir, '.JPG')
crop(args)
# Out:
#   0%|          | 0/53 [00:00<?, ?it/s]
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f4ac02d2dc0>
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
#   2%|▏         | 1/53 [00:01<01:40,  1.94s/it]
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f4adddf48b0>
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
#   4%|▍         | 2/53 [00:03<01:35,  1.88s/it]
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f4ac0213700>
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
#   6%|▌         | 3/53 [00:05<01:35,  1.92s/it]
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f4addd898b0>
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
#   8%|▊         | 4/53 [00:07<01:32,  1.89s/it]
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f4addcb5790>
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/anaconda/envs/azureml_py38/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
#   8%|▊         | 4/53 [00:09<01:54,  2.34s/it]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 args = DebugArgs(input_dir, output_dir, '.JPG')
# ----> 2 crop(args)
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-gpu-changins/code/Users/aurelie.dejong.agroscope/Agroscope_codes/other_codes/crop_frames/crop_frame.py:112, in crop(args)
#     109 print('\n ** Filename error', len(points), fn)
#     111 if len(points) < n_point:
# --> 112     line_list = getLines(mask1, n_clust, 2500, 1200)
#     113     points = getPoints(H,W,line_list)
#     115     if len(points) < n_point:
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-gpu-changins/code/Users/aurelie.dejong.agroscope/Agroscope_codes/other_codes/crop_frames/crop_frame.py:52, in crop.<locals>.getLines(mask1, n, p1, p2)
#      48 def getLines(mask1, n, p1 = 1200, p2 = 800): #1500, 800
#      49
#      50             #### Get lines
#      51             lines = cv2.HoughLinesP(mask1.astype('uint8'), 1, np.pi/180, p1, minLineLength = p2, maxLineGap=800) #1, pi/180, 2500, 1200, 800
# ---> 52             out = lines.reshape((lines.shape[0], 4))
#      54             #### Cluster the lines in 4 groups
#      55             kmeans = KMeans(n_clusters = n)
#
# AttributeError: 'NoneType' object has no attribute 'reshape'
