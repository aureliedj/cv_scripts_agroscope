# %%
import os
from crop_frame import DebugArgs, crop
from glob import glob
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
input_dir = os.getcwd() + '/../../../data/photos_zenitales/2022.09.08'
# create output directory
if input_dir + '_crop' not in glob(input_dir +'_crop'):
    output_dir = os.makedirs(input_dir + '_crop')
else:
    output_dir = input_dir + '_crop'

# %%
args = DebugArgs(input_dir, output_dir, '.JPG')
crop(args)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 args = DebugArgs(input_dir, output_dir, '.JPG')
# ----> 2 crop(args)
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-gpu-changins/code/Users/aurelie.dejong.agroscope/Agroscope_codes/other_codes/crop_frames/crop_frame.py:93, in crop(args)
#      87 hsvImg = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#      90 mask1 =  getRedFrame(hsvImg, plot = False)
# ---> 93 line_list = getLines(mask1, n_clust)
#      95 #Check
#      96 if len(line_list)!= n_clust:
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-gpu-changins/code/Users/aurelie.dejong.agroscope/Agroscope_codes/other_codes/crop_frames/crop_frame.py:51, in crop.<locals>.getLines(mask1, n, p1, p2)
#      47 def getLines(mask1, n, p1 = 1200, p2 = 800): #1500, 800
#      48
#      49             #### Get lines
#      50             lines = cv2.HoughLinesP(mask1.astype('uint8'), 1, np.pi/180, p1, minLineLength = p2, maxLineGap=800) #1, pi/180, 2500, 1200, 800
# ---> 51             out = lines.reshape((lines.shape[0],4))
#      53             #### Cluster the lines in 4 groups
#      54             kmeans = KMeans(n_clusters = n)
#
# AttributeError: 'NoneType' object has no attribute 'reshape'
